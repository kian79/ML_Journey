# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
train_path = os.path.join('data','train.csv')
test_path = os.path.join('data','test.csv')

# %%
train_df = pd.read_csv(train_path)

# %%
train_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
oe = OrdinalEncoder()
train_df['MSZoning'] = oe.fit_transform(train_df[['MSZoning']])

# %%
train_df.MSZoning.value_counts()
# Out:
# 3.0    1151
# 4.0     218
# 1.0      65
# 2.0      16
# 0.0      10
# Name: MSZoning, dtype: int64

# %%
imputer = SimpleImputer(strategy="median")
train_df['LotFrontage'] = imputer.fit_transform(train_df[['LotFrontage']])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260     3.028767    69.863699   10516.828082
# std     421.610009    42.300571     0.632017    22.027677    9981.264932
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     3.000000    60.000000    7553.500000
# 50%     730.500000    50.000000     3.000000    69.000000    9478.500000
# 75%    1095.250000    70.000000     3.000000    79.000000   11601.500000
# max    1460.000000   190.000000     4.000000   313.000000  215245.000000
#
#        OverallQual  OverallCond    YearBuilt  YearRemodAdd   MasVnrArea  ...  \
# count  1460.000000  1460.000000  1460.000000   1460.000000  1452.000000  ...
# mean      6.099315     5.575342  1971.267808   1984.865753   103.685262  ...
# std       1.382997     1.112799    30.202904     20.645407   181.066207  ...
# ...

# %%
train_df.Street = oe.fit_transform(train_df[['Street']])

# %%
train_df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260     3.028767    69.863699   10516.828082
# std     421.610009    42.300571     0.632017    22.027677    9981.264932
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     3.000000    60.000000    7553.500000
# 50%     730.500000    50.000000     3.000000    69.000000    9478.500000
# 75%    1095.250000    70.000000     3.000000    79.000000   11601.500000
# max    1460.000000   190.000000     4.000000   313.000000  215245.000000
#
#             Street  OverallQual  OverallCond    YearBuilt  YearRemodAdd  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000   1460.000000  ...
# mean      0.995890     6.099315     5.575342  1971.267808   1984.865753  ...
# std       0.063996     1.382997     1.112799    30.202904     20.645407  ...
# ...

# %%
train_df.Alley = train_df.Alley.replace(np.nan, 'No', regex=True)

# %%
train_df.Alley = oe.fit_transform(train_df[['Alley']])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   float64
#  6   Alley          1460 non-null   float64
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_df.LotShape = oe.fit_transform(train_df[['LotShape']])

# %%
train_df[train_df.columns[8:17]] = oe.fit_transform(train_df[train_df.columns[8:17]])

# %%
train_df[train_df.columns[21:25]] = oe.fit_transform(train_df[train_df.columns[21:25]])

# %%
train_df.MasVnrType.value_counts()
# Out:
# None       872
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64

# %%
train_df.MasVnrType = train_df.MasVnrType.replace(np.nan, 'None', regex=True)

# %%
train_df.MasVnrType = oe.fit_transform(train_df[['MasVnrType']])

# %%
imputer = SimpleImputer(strategy="median")
train_df['MasVnrArea'] = imputer.fit_transform(train_df[['MasVnrArea']])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   float64
#  6   Alley          1460 non-null   float64
#  7   LotShape       1460 non-null   float64
#  8   LandContour    1460 non-null   float64
#  9   Utilities      1460 non-null   float64
#  10  LotConfig      1460 non-null   float64
#  11  LandSlope      1460 non-null   float64
#  12  Neighborhood   1460 non-null   float64
#  13  Condition1     1460 non-null   float64
#  14  Condition2     1460 non-null   float64
#  15  BldgType       1460 non-null   float64
#  16  HouseStyle     1460 non-null   float64
# ...

# %%
train_df.BsmtQual.value_counts()
# Out:
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64

# %%
train_df.BsmtQual = train_df.BsmtQual.replace(np.nan, 'No', regex=True)

# %%
train_df.BsmtCond = train_df.BsmtCond.replace(np.nan, 'No', regex=True)

# %%
train_df.BsmtExposure = train_df.BsmtExposure.replace(np.nan, 'No', regex=True)

# %%
train_df.BsmtFinType1 = train_df.BsmtFinType1.replace(np.nan, 'No', regex=True)

# %%
train_df.BsmtFinType2 = train_df.BsmtFinType2.replace(np.nan, 'No', regex=True)

# %%
train_df[train_df.columns[27:34]] = oe.fit_transform(train_df[train_df.columns[27:34]])

# %%
train_df[['BsmtFinType2']] = oe.fit_transform(train_df[['BsmtFinType2']])

# %%
train_df.Electrical = train_df.Electrical.replace(np.nan, 'SBrkr', regex=True)

# %%
train_df[train_df.columns[39:43]] = oe.fit_transform(train_df[train_df.columns[39:43]])

# %%
train_df[['KitchenQual']] = oe.fit_transform(train_df[['KitchenQual']])

# %%
train_df[['Functional']] = oe.fit_transform(train_df[['Functional']])

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   float64
#  6   Alley          1460 non-null   float64
#  7   LotShape       1460 non-null   float64
#  8   LandContour    1460 non-null   float64
#  9   Utilities      1460 non-null   float64
#  10  LotConfig      1460 non-null   float64
#  11  LandSlope      1460 non-null   float64
#  12  Neighborhood   1460 non-null   float64
#  13  Condition1     1460 non-null   float64
#  14  Condition2     1460 non-null   float64
#  15  BldgType       1460 non-null   float64
#  16  HouseStyle     1460 non-null   float64
# ...

# %%
X_test = train_df.drop(columns=['PoolQC','Fence','MiscFeature','FireplaceQu'])

# %%
X_test[X_test.columns[74:76]] = oe.fit_transform(X_test[X_test.columns[74:76]])

# %%
X_test.GarageQual = X_test.GarageQual.replace(np.nan, 'No', regex=True)

# %%
X_test.GarageCond = X_test.GarageCond.replace(np.nan, 'No', regex=True)

# %%
X_test.GarageYrBlt = X_test.GarageYrBlt.replace('No', np.nan, regex=True)

# %%
X_test.GarageFinish = X_test.GarageFinish.replace(np.nan, 'No', regex=True)

# %%
X_test.GarageType = X_test.GarageType.replace(np.nan, 'No', regex=True)

# %%
X_test[X_test.columns[62:65]] = oe.fit_transform(X_test[X_test.columns[62:65]])

# %%
X_test[X_test.columns[57:58]] = oe.fit_transform(X_test[X_test.columns[57:58]])

# %%
X_test[X_test.columns[59:60]] = oe.fit_transform(X_test[X_test.columns[59:60]])

# %%
imputer = SimpleImputer(strategy="median")
X_test['GarageYrBlt'] =imputer.fit_transform(X_test[['GarageYrBlt']])

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   float64
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   float64
#  6   Alley          1460 non-null   float64
#  7   LotShape       1460 non-null   float64
#  8   LandContour    1460 non-null   float64
#  9   Utilities      1460 non-null   float64
#  10  LotConfig      1460 non-null   float64
#  11  LandSlope      1460 non-null   float64
#  12  Neighborhood   1460 non-null   float64
#  13  Condition1     1460 non-null   float64
#  14  Condition2     1460 non-null   float64
#  15  BldgType       1460 non-null   float64
#  16  HouseStyle     1460 non-null   float64
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
X_train = X_test.drop()
